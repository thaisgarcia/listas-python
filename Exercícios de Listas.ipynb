# %% [markdown]
# 1. Escreva um programa que recebe como entrada um número inteiro positivo n. Em seguida, seu programa deve ler n números inteiros e adicioná-los em uma lista. Por fim, seu programa receberá um número inteiro x e deve verificar se x pertence ou não à lista.

# %%
n = int(input("Digite o número de elementos da lista: "))
lista = []

for i in range(n):
  elemento = int(input(f"Digite o {i+1}º elemento: "))
  lista.append(elemento)

x = int(input("Digite o elemento a ser buscado: "))
if x in lista:
  print("O elemento pertence à lista.")
else:
  print("O elemento não pertence à lista.")
# Out:
# Digite o número de elementos da lista: 5
# Digite o 1º elemento: 3
# Digite o 2º elemento: 6
# Digite o 3º elemento: 9
# Digite o 4º elemento: 12
# Digite o 5º elemento: 15
# Digite o elemento a ser buscado: 7
# O elemento não pertence à lista.

# %% [markdown]
# 2. Escreva um programa que leia números positivos e os armazene numa lista (até que um número não positivo seja fornecido). Por fim, seu programa receberá um número inteiro x e deve verificar se x pertence ou não à lista.

# %%
lista = []
elemento = int(input("Digite um número positivo: "))

while elemento > 0:
  lista.append(elemento)
  elemento = int(input("Digite um número positivo: "))

x = int(input("Digite o elemento a ser buscado: "))
if x in lista:
  print("O elemento pertence à lista.")
else:
  print("O elemento não pertence à lista.")
# Out:
# Digite um número positivo: 3
# Digite um número positivo: 4
# Digite um número positivo: 5
# Digite um número positivo: -2
# Digite o elemento a ser buscado: 3
# O elemento pertence à lista.
